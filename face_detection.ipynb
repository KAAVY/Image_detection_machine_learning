# %% [markdown]
# <a href="https://colab.research.google.com/github/KAAVY/Image_detection_machine_learning/blob/master/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=4dd1959a5fccd228f7f5c816da048e412ffa544cf7c6895dae677918e7000403
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
pip install opencv-python

# %%
import numpy as np
import cv2
import face_recognition
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = face_recognition.load_image_file("/content/kaavy (1).jpg")

# %%
plt.imshow(image)
plt.show();

# %%
face_locations = face_recognition.face_locations(image,model='cnn')
face_locations
# Out:
# [(58, 167, 157, 69)]

# %%
top = 58
bottom = 167
left = 157
right = 69

# %%
#print (top)
# Out:
# [(58,

# %%
for face_location in face_locations:
    img = cv2.rectangle(image,(left,top),(right,bottom),(256,256,0),2)
    plt.imshow(img)
    plt.show();
