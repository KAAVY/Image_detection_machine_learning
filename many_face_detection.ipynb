# %% [markdown]
# <a href="https://colab.research.google.com/github/KAAVY/Image_detection_machine_learning/blob/master/many_face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2, glob
import matplotlib.pyplot as plt

# %%
gimage = glob.glob("/content/DSC03442.JPG")
detect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
for timage in gimage:
    image = cv2.imread(timage)
    graying = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    face = detect.detectMultiScale(graying,1.25,3)
    for(x,y,w,h) in face:
        cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
        plt.imshow(image)
        plt.show();
